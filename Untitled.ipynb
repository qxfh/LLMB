# %%
# %load_ext autoreload
# %autoreload 2
from Text_mining import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from Text_mining import *
#
# File ~/BM/BatteryMiningCopy/Automatic-battery-collector/Text_mining.py:6
#       4 import traceback
#       5 from libs.Preprocess import *
# ----> 6 from libs.caption.Caption_miner import *
#       7 from libs.result.Result_miner import *
#       8 from libs.experimental.Experimental_miner import *
#
# File ~/BM/BatteryMiningCopy/Automatic-battery-collector/libs/caption/Caption_miner.py:2
#       1 import json
# ----> 2 from langchain.prompts import PromptTemplate
#       3 from langchain.chat_models import ChatOpenAI
#       4 from .prompt import PROMPT_CAPTION, PROMPT_FIGURE
#
# ModuleNotFoundError: No module named 'langchain'

# %%
from Text_mining import *
from libs.merge.Text_Graph_merge import *
from libs.merge.Cell_merge import *
from libs.Preprocess import *
from SMILES.get_smiles import *
from crawling.download_thread import *
from crawling.elsevier_download import * 
from crawling.elsevier_search import * 
from crawling.func import * 
from crawling.get_xrd_paper import *

# %%
from libs.reader.error import *
from libs.reader.html import *
from libs.reader.pdf import *
from libs.reader.reader_meta import *
from libs.reader.xml import *

# %%
import regex

# %%
import sys
sys.version
# Out:
# '3.8.18 | packaged by conda-forge | (default, Dec 23 2023, 17:21:28) \n[GCC 12.3.0]'
